# %%
## Connect to google colab

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Import data reading libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## Load data

amazon_data = pd.read_csv("/content/drive/MyDrive/Amazon/Amazon_100000_data/Cleaned_Amazon_data.csv")
amazon_data.head()
# Out:
#                                                 Text  Score
# 0  product arrived labeled jumbo salted peanut pe...      1
# 1  cat happily eating felidae platinum two year g...      1
# 2        candy red flavor plan chewy would never buy      1
# 3        oatmeal good mushy soft like quaker oat way      1
# 4                    arrived day stale could eat bag      1

# %%
## Taking only text data

text = amazon_data.Text

# %%
## create the tokenizer
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()

# %%
## fit the tokenizer on the documents

tokenizer.fit_on_texts(text)

# %%
## summarize what was learned

print("word_counts: \n",tokenizer.word_counts)
print("\n\ndocument_count: \n",tokenizer.document_count)
print("\n\nword_index: \n",tokenizer.word_index)
print("\n\nword_docs: \n",tokenizer.word_docs)
# Out:
# word_counts:
#  OrderedDict([('product', 84410), ('arrived', 6568), ('labeled', 876), ('jumbo', 124), ('salted', 694), ('peanut', 8540), ('actually', 11054), ('small', 13806), ('sized', 1698), ('unsalted', 206), ('sure', 13954), ('error', 460), ('vendor', 1212), ('intended', 724), ('represent', 88), ('cat', 22210), ('happily', 508), ('eating', 12112), ('felidae', 112), ('platinum', 72), ('two', 20502), ('year', 17612), ('got', 18268), ('new', 10468), ('bag', 36234), ('shape', 1706), ('food', 55728), ('different', 14018), ('tried', 27810), ('first', 26682), ('put', 12046), ('bowl', 4282), ('sit', 1268), ('full', 7662), ('kitty', 1146), ('touch', 2440), ('noticed', 3878), ('similar', 4220), ('review', 18032), ('related', 372), ('formula', 4714), ('change', 4546), ('past', 3854), ('unfortunately', 5658), ('need', 13218), ('find', 22676), ('eat', 25238), ('candy', 7652), ('red', 4246), ('flavor', 75344), ('plan', 1934), ('chewy', 3122), ('would', 60564), ('never', 14444), ('buy', 31172), ('oatmeal', 3388), ('good', 75354), ('mushy', 920), ('soft', 4784), ('like', 114400), ('quaker', 798), ('oat', 2006), ('way', 20720), ('day', 21190), ('stale', 3850), ('could', 19600), ('buyer', 1178), ('beware', 1608), ('please', 3670), ('sweetener', 3944), ('everybody', 286), ('maltitol', 310), ('alcohol', 732), ('sugar', 23820), ('undigestible', 28), ('body', 2740), ('know', 19816), ('short', 2498), ('time', 36574), ('consuming', 624), ('one', 73322), ('unsuspecting', 86), ('many', 14302), ('cannot', 3998), ('digest', 606), ('extreme', 510), ('intestinal', 258), ('bloating', 162), ('cramping', 144), ('massive', 184), ('amount', 9426), ('gas', 1708), ('person', 2364), ('experience', 4432), ('nausea', 242), ('diarrhea', 1410), ('headache', 494), ('also', 29590), ('experienced', 862), ('learned', 1084), ('lesson', 414), ('hard', 12564), ('ago', 4888), ('fell', 990), ('love', 41398), ('free', 15454), ('chocolate', 26118), ('suzanne', 28), ('sommers', 24), ('used', 20218), ('sell', 3228), ('thought', 16342), ('found', 18070), ('nirvana', 166), ('taste', 94664), ('bliss', 116), ('lived', 548), ('terrible', 3470), ('side', 6142), ('effect', 2884), ('kicked', 116), ('discomfort', 204), ('unlike', 1728), ('anything', 9694), ('ever', 9658), ('felt', 2794), ('blew', 140), ('balloon', 54), ('painful', 214), ('abdominal', 94), ('symptom', 540), ('passed', 514), ('unpleasant', 1536), ('though', 14662), ('believe', 4244), ('low', 8530), ('calorie', 12476), ('culprit', 140), ('gone', 2940), ('stopped', 2084), ('hunch', 34), ('something', 18462), ('confirmed', 234), ('later', 3448), ('purchased', 9924), ('delicious', 8696), ('popcorn', 7194), ('local', 8686), ('market', 3974), ('amazing', 2832), ('looking', 11500), ('label', 4860), ('wondering', 640), ('possibly', 816), ('make', 36958), ('yummy', 2282), ('sugarfree', 118), ('treat', 24318), ('heart', 1578), ('sank', 34), ('followed', 1388), ('little', 31378), ('asterisk', 34), ('next', 6310), ('bottom', 4126), ('read', 6702), ('tiny', 2958), ('letter', 388), ('thank', 2246), ('goodness', 936), ('eaten', 2872), ('still', 20396), ('ended', 2642), ('much', 38506), ('shorter', 180), ('duration', 54), ('people', 11142), ('use', 28108), ('content', 4510), ('others', 6316), ('bad', 18686), ('reaction', 1438), ('case', 9204), ('tea', 48740), ('whole', 11128), ('brunch', 20), ('artifial', 4), ('returnable', 318), ('wasted', 874), ('buck', 1464), ('fed', 1492), ('golden', 882), ('retriever', 362), ('hated', 638), ('gave', 7758), ('buying', 11210), ('super', 3570), ('expensive', 8406), ('single', 4192), ('store', 19658), ('box', 29718), ('amazon', 35626), ('selling', 1414), ('hazelnut', 1834), ('coffee', 73422), ('creamer', 1814), ('favorite', 11186), ('truly', 1994), ('seriously', 1422), ('tasteless', 1150), ('come', 13924), ('better', 29628), ('tasting', 8450), ('special', 3456), ('bar', 14758), ('cookie', 6030), ('snack', 11966), ('pack', 16304), ('season', 688), ('combine', 362), ('else', 5624), ('share', 1146), ('long', 9734), ('sa ...
#
#
# document_count:
#  200000
#
#
# word_index:
#  {'like': 1, 'taste': 2, 'product': 3, 'good': 4, 'flavor': 5, 'coffee': 6, 'one': 7, 'would': 8, 'food': 9, 'tea': 10, 'dog': 11, 'get': 12, 'great': 13, 'love': 14, 'really': 15, 'much': 16, 'make': 17, 'time': 18, 'bag': 19, 'amazon': 20, 'cup': 21, 'little': 22, 'buy': 23, 'even': 24, 'box': 25, 'better': 26, 'also': 27, 'use': 28, 'tried': 29, 'try': 30, 'price': 31, 'first': 32, 'chocolate': 33, 'eat': 34, 'well': 35, 'drink': 36, 'treat': 37, 'sugar': 38, 'think': 39, 'find': 40, 'water': 41, 'cat': 42, 'brand': 43, 'made': 44, 'bought': 45, 'day': 46, 'way': 47, 'ingredient': 48, 'bit': 49, 'two': 50, 'still': 51, 'used': 52, 'say': 53, 'thing': 54, 'sweet': 55, 'know': 56, 'give': 57, 'store': 58, 'could': 59, 'best': 60, 'chip': 61, 'bad': 62, 'something': 63, 'however': 64, 'got': 65, 'found': 66, 'review': 67, 'year': 68, 'since': 69, 'want': 70, 'order': 71, 'lot': 72, 'thought': 73, 'pack': 74, 'package': 75, 'mix': 76, 'free': 77, 'star': 78, 'work': 79, 'bar': 80, 'though': 81, 'never': 82, 'smell': 83, 'le': 84, 'many': 85, 'back': 86, 'nice': 87, 'different': 88, 'sure': 89, 'come': 90, 'ordered': 91, 'quality': 92, 'small': 93, 'strong': 94, 'old': 95, 'organic': 96, 'need': 97, 'enough': 98, 'pretty': 99, 'stuff': 100, 'recommend': 101, 'see': 102, 'hot': 103, 'problem': 104, 'hard': 105, '
retriever': 334, 'box': 19174, 'store': 16840, 'coffee': 26608, 'favorite': 10276, 'selling': 1338, 'single': 3680, 'hazelnut': 1280, 'creamer': 1330, 'amazon': 25962, 'truly': 1892, 'tasteless': 1078, 'come': 12628, 'combine': 356, 'share': 1110, 'pack': 12360, 'tasting': 7912, 'better': 25380, 'bar': 6442, 'season': 618, 'seriously': 1378, 'snack': 9156, 'else': 5362, 'special': 3094, 'cookie': 3296, 'half': 8078, 'return': 3434, 'damaged': 1026, 'brand': 16416, 'back': 12154, 'dried': 3394, 'shelf': 1920, 'refund': 1596, 'old': 11302, 'sign': 608, 'away': 9386, 'cook': 2504, 'clear': 2124, 'bean': 5026, 'throw': 2802, 'sat': 564, 'ask': 1272, 'serving': 5308, 'prime': 1042, 'skin': 1334, 'long': 8842, 'even': 25826, 'fifty': 130, 'somewhere': 968, 'smaller': 3898, 'banana': 1376, 'consistency': 2724, 'look': 10160, 'stuff': 10496, 'runt': 36, 'yucky': 278 ...

# %%
## integer encode sequences

text_numeric = tokenizer.texts_to_sequences(text)
print(text_numeric[0])
# Out:
# [3, 252, 1471, 4771, 1731, 192, 192, 138, 93, 893, 3614, 89, 2231, 1156, 1688, 5713, 3, 4771]

# %%
## pad sequences with 0 values.
## here we using padding = 'pre', cause if two sentence after converting to numerical value, is not of same length , we are using zero before sentences and make them of equal length.
## if we put padding = 'post', then zero will add after sentences. 

from tensorflow.keras.preprocessing.sequence import pad_sequences

sent_length = max([len(i) for i in text_numeric])
pad_seqence_text = pad_sequences(text_numeric, maxlen=sent_length, padding = 'post')
print(pad_seqence_text)
# Out:
# [[   3  252 1471 ...    0    0    0]
#  [  42 2093  108 ...    0    0    0]
#  [ 219  400    5 ...    0    0    0]
#  ...
#  [   3   13 1755 ...    0    0    0]
#  [ 170  177  627 ...    0    0    0]
#  [  29  220   43 ...    0    0    0]]

# %%
import pickle

# saving
with open('/content/drive/MyDrive/Amazon/Amazon_100000_data/tokenizer_1.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# loading
with open('/content/drive/MyDrive/Amazon/Amazon_100000_data/tokenizer_1.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
import io, json

# saving
tokenizer_json = tokenizer.to_json()
with io.open('/content/drive/MyDrive/Amazon/Amazon_100000_data/tokenizer_1.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(tokenizer_json, ensure_ascii=False))

# loading
from tensorflow.keras.preprocessing.text import tokenizer_from_json
with open('/content/drive/MyDrive/Amazon/Amazon_100000_data/tokenizer_1.json') as f:
    data = json.load(f)
    tokenizer = tokenizer_from_json(data)

# %%
## save data as NPZ file

np.savez_compressed("/content/drive/MyDrive/Amazon/Amazon_100000_data/Amazon_text_to_numeric.npz", a=np.array(pad_seqence_text), b=np.array(amazon_data.Score))

# %%
## Load data

loaded = np.load("/content/drive/MyDrive/Amazon/Amazon_100000_data/Amazon_text_to_numeric.npz")
text_numeric = loaded['a']
print(text_numeric)
# Out:
# [[   3  252 1471 ...    0    0    0]
#  [  42 2093  108 ...    0    0    0]
#  [ 219  400    5 ...    0    0    0]
#  ...
#  [   3   13 1755 ...    0    0    0]
#  [ 170  177  627 ...    0    0    0]
#  [  29  220   43 ...    0    0    0]]

# %%
score = loaded['b']
print(score)
# Out:
# [1 1 1 ... 5 5 5]
